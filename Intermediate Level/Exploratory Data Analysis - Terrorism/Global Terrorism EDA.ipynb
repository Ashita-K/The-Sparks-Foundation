# %% [markdown]
# # ASHITA K
# # INTERMEDIATE TASK LEVEL 4
# # Exploratory Data Analysis - Terrorism

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset

# %%
terrorism = pd.read_csv("globalterrorismdb_0718dist.csv")

# %%
terrorism.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
terrorism.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# # Data Analysis

# %%
terrorism.shape
# Out:
# (181691, 135)

# %%
terrorism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terrorism.isna().any()
# Out:
# eventid       False
# iyear         False
# imonth        False
# iday          False
# approxdate     True
#               ...
# INT_LOG       False
# INT_IDEO      False
# INT_MISC      False
# INT_ANY       False
# related        True
# Length: 135, dtype: bool

# %%
terrorism.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
terrorism.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
terrorism.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
terrorism=terrorism[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
terrorism.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
terrorism.corr()
# Out:
#                Year     Month       Day  latitude  longitude    Killed  \
# Year       1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# Month      0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# Day        0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# latitude   0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# longitude  0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# Killed     0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# Wounded    0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
#
#             Wounded
# Year       0.015273
# Month      0.002938
# Day       -0.001268
# latitude   0.015988
# longitude  0.000223
# Killed     0.534375
# Wounded    1.000000

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(15,8))
correlation=terrorism.corr()
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
terrorism["Country"].value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(40,10))
sns.countplot(terrorism['Country'])
plt.title("Countries VS Count of Terrorism Attacks")
plt.xticks(rotation=90)
plt.show()

# %%
terrorism["Country"].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
terrorism["Country"].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
terrorism["Region"].value_counts().head(10)
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
sns.set(rc={'figure.figsize':(25,10)})
sns.countplot(x="Region",data=terrorism)
plt.title("Regions VS Count of Terrorism Attacks")
plt.show()

# %%
terrorism["Region"].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
terrorism["Region"].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='Region'>

# %%
sns.set(rc={'figure.figsize':(25,10)})
sns.countplot(x="AttackType",data=terrorism)
plt.title("Attack Type VS Count of Terrorism Attacks")
plt.show()

# %%
terrorism["AttackType"].value_counts().head(10)
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
terrorism["AttackType"].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
terrorism["AttackType"].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='AttackType'>

# %%
terrorism["Target"].value_counts().head(10)
# Out:
# Civilians        6461
# Unknown          5918
# Soldiers         3157
# Patrol           2942
# Checkpoint       2905
# Vehicle          2785
# Officers         1787
# Village          1679
# Military Unit    1533
# Bus              1335
# Name: Target, dtype: int64

# %%
plt.figure(figsize=(25,10))
sns.countplot(terrorism['Target_type'])
plt.title("Target Type VS Count of Terrorism Attacks")
plt.xticks(rotation=90)
plt.show()

# %%
terrorism["Target_type"].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
terrorism["Target_type"].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='Target_type'>

# %%
terrorism["Weapon_type"].value_counts().head(10)
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Name: Weapon_type, dtype: int64

# %%
sns.set(rc={'figure.figsize':(25,10)})
sns.countplot(x="Weapon_type",data=terrorism)
plt.title("Weapon Type VS Count of Terrorism Attacks")
plt.show()

# %%
terrorism["Weapon_type"].value_counts().head(5).plot.pie()
# Out:
# <AxesSubplot:ylabel='Weapon_type'>

# %%
terrorism["Year"].value_counts().head(10)
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# Name: Year, dtype: int64

# %%
terrorism["Year"].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.barplot(x=terrorism["Group"].value_counts()[1:11], y=terrorism["Group"].value_counts()[1:11].index, palette='viridis')
# Out:
# <AxesSubplot:xlabel='Group'>

# %% [markdown]
# # INFERENCE:---
# # Iraq is the hot zone of terrorism
# # Middle East and North America had the highest number of terrorism attack
# # Mostly attacked by Bombing/Explosion
# # Mostly used weapon type was Explosives
# # The most targeted type was Private Citizens and Property
# # Most number of terrorism attacks happened in the year 2014
# # Tabilan is the frequent terrorist group
